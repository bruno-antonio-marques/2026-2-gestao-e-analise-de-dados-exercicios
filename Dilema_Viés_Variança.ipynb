# %% [markdown]
# <a href="https://colab.research.google.com/github/bruno-antonio-marques/2026-2-gestao-e-analise-de-dados-exercicios/blob/main/Dilema_Vi%C3%A9s_Varian%C3%A7a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercícios de TREINO-TESTE

# %% [markdown]
# Exercício 2 — Regressão Logística: aprovação de crédito

# %% [markdown]
# Bibliotecas

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### dados de entrada (x) e saída (y) do modo treino

# %%
X_train = np.array([
    [420],
    [460],
    [500],
    [540],
    [600],
    [650],
    [720]
])

y_train = np.array([
    0,
    0,
    0,
    0,
    1,
    1,
    1
])

# %% [markdown]
# Dados de entrada (x) e saída (y) do modo teste

# %%
X_test = np.array([
    [480],
    [580],
    [680]
])

y_test = np.array([
    0,
    1,
    1
])

# %% [markdown]
# modelo = LinearRegression()

# %%
modelo = LogisticRegression()

# %% [markdown]
# Treino dos dados de treino (Gerar seu modelo)

# %%
modelo.fit(X_train, y_train)

w = modelo.coef_[0][0]
b = modelo.intercept_[0]

# %% [markdown]
# Valores dos parâmetros "w" e "b"

# %%
print("w =", w)
print("b =", b)

# %% [markdown]
# probabilidades de cada classe para seus dados de teste

# %%
probabilidades = modelo.predict_proba(X_test)[:, 1]

print("Probabilidades:", probabilidades)

# %% [markdown]
# prever a classe real (0 ou 1) para seus dados de teste

# %%
y_pred = modelo.predict(X_test)

print("Classes previstas:", y_pred)

# %% [markdown]
# avaliar o desempenho do seu modelo de regressão logística, calculando sua precisão nos dados de teste.

# %%
acc = accuracy_score(y_test, y_pred)

print("Acurácia teste =", acc)

# %% [markdown]
# Regressão Logística treinado, para prever o status de aprovação e sua probabilidade para um novo cliente, ainda não conhecido .

# %%
novo_cliente = np.array([[560]])

prob = modelo.predict_proba(novo_cliente)[0][1]
classe = modelo.predict(novo_cliente)[0]

# %% [markdown]
#  resultados das previsões feitas

# %%
print("Probabilidade de aprovação =", prob)
print("Classe prevista =", classe)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

X_train = np.array([
    [420],
    [460],
    [500],
    [540],
    [600],
    [650],
    [720]
])

y_train = np.array([
    0,
    0,
    0,
    0,
    1,
    1,
    1
])

X_test = np.array([
    [480],
    [580],
    [680]
])

y_test = np.array([
    0,
    1,
    1
])

modelo = LogisticRegression()

modelo.fit(X_train, y_train)

w = modelo.coef_[0][0]
b = modelo.intercept_[0]

print("w =", w)
print("b =", b)

probabilidades = modelo.predict_proba(X_test)[:, 1]

print("Probabilidades:", probabilidades)

y_pred = modelo.predict(X_test)

print("Classes previstas:", y_pred)

acc = accuracy_score(y_test, y_pred)

print("Acurácia teste =", acc)

novo_cliente = np.array([[560]])

prob = modelo.predict_proba(novo_cliente)[0][1]
classe = modelo.predict(novo_cliente)[0]

print("Probabilidade de aprovação =", prob)
print("Classe prevista =", classe)
# Out:
# w = 0.19149055694452302
# b = -109.14985296540712
# Probabilidades: [3.27492536e-08 8.71542897e-01 9.99999999e-01]
# Classes previstas: [0 1 1]
# Acurácia teste = 1.0
# Probabilidade de aprovação = 0.12840437983426106
# Classe prevista = 0
